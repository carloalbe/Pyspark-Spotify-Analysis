# %%
import findspark
findspark.init()

# %%
import pyspark

# %%
from pyspark.sql import SparkSession
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.window import Window
from pyspark.ml.stat import Correlation
from pyspark.sql.types import IntegerType,BooleanType,DateType,FloatType, StringType
import matplotlib.pyplot as plt 
import seaborn as sns
import pyspark.sql.types as T
import pandas as pd

# %%
spark = SparkSession \
    .builder \
    .appName("Python Spark SQL basic example") \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()

def fudf(val):
    return functools.reduce(lambda x, y:x+y, val)

# %%
df = spark.read.json('C:\\Users\\pasqu\\Desktop\\Università\\Distributed Data Analysis and Mining\\cleaned_dataset')

# %%
df.count()
# Out:
# 583363

# %%
df.show()
# Out:
# +------------+------------------+--------------------+---------------------+------------+-----------+------+--------------------+--------------------+----------------+---+--------+--------+----+----------------+------------+-----------+--------------------+---------------------+-------+--------------+-------+
# |acousticness|               age|avg_artist_followers|avg_artist_popularity|danceability|duration_ms|energy|              genres|            id_track|instrumentalness|key|liveness|loudness|mode|popularity_track|release_date|speechiness|sum_artist_followers|sum_artist_popularity|  tempo|time_signature|valence|
# +------------+------------------+--------------------+---------------------+------------+-----------+------+--------------------+--------------------+----------------+---+--------+--------+----+----------------+------------+-----------+--------------------+---------------------+-------+--------------+-------+
# |       0.658|41.821917808219176|              5403.5|                 40.0|       0.602|     156067| 0.552|[classic czech po...|00AeAaSNbe92PRrst...|             0.0|  0|  0.0972|  -6.667|   1|               3|  1980-01-01|      0.404|               10807|                   80|182.229|             3|   0.65|
# |       0.543|45.824657534246576|             19833.0|                 43.0|        0.77|     220133| 0.891|[afrobeat, afropo...|00DJt4PjkzeXhKKVD...|         7.96E-4|  1|  0.0684|  -7.306|   1|               9|  1976-01-01|      0.172|               19833|                   43|135.573|             4|  0.898|
# |      4.8E-5|25.673972602739727|            874600.0|                 68.0|       0.212|     250960| 0.986|[alternative meta...|00HgVIkZrAL8WjAN9...|           0.918|  0|   0.324|   -6.69|   0|              33|  1996-02-20|       0.14|              874600|                   68|140.917|             4|  0.231|
# |       0.144|31.813698630136987|             69129.0|                 42.0|       0.362|     457040| 0.453|[corrosion, dark ...|00Lx2f8NRiFKMGWa0...|           0.827| 11|   0.117| -17.744|   0|              35|  1990-01-01|     0.0398|               69129|                   42|118.853|             4|  0.257|
# |       0.957| 4.071232876712329|           1709414.0|                 68.0|       0.343|     282891| 0.225|[brazilian rock, ...|00fzPML4lrNag28OP...|         2.49E-4|  1|   0.661| -14.937|   0|              52|  2017-09-22|     0.0384|             1709414|                   68|144.533|             4|  0.101|
# |       0.119|13.802739726027397|           2092689.0|                 69.0|       0.893|     217000| 0.614|[brazilian rock, ...|00hUjt7XHLHwUB1L2...|         9.76E-4|  7|  0.0952|  -5.331|   1|              42|  2008-01-01|     0.0362|             2092689|                   69|120.021|             4|  0.958|
# |        0.96| 71.84109589041095|           1921672.0|                 63.0|       0.351|     545107|0.0944|[classical perfor...|00jrUA3PWiKaMpWJv...|          0.0339|  8|   0.083| -17.481|   1|               0|  1950-01-01|     0.0413|             3843344|                  126| 107.86|             4|  0.237|
# |       0.168|6.6657534246575345|              5109.0|                 37.0|       0.422|     256933| 0.912|                  []|00pEXGlxPsGuLm4Nq...|             0.0|  5|   0.129|  -3.806|   0|              49|  2015-02-18|     0.0799|                5109|                   37| 97.573|             4|  0.616|
# +------------+------------------+--------------------+---------------------+------------+-----------+------+--------------------+--------------------+----------------+---+--------+--------+----+----------------+------------+-----------+--------------------+---------------------+-------+--------------+-------+
# only showing top 20 rows

# %% [markdown]
# # Data Transformation

# %% [markdown]
# Vector Assembler. A vector assembler is a transformer that converts a set of features into a single vector column often referred to as an array of features

# %%
from pyspark.ml.linalg import Vectors
from pyspark.ml.feature import VectorAssembler

assembler = VectorAssembler(
    inputCols=["avg_artist_popularity","duration_ms", "danceability", "loudness", "speechiness","acousticness","instrumentalness","liveness","valence","tempo","time_signature","age", "mode","sum_artist_followers","sum_artist_popularity"],
    outputCol="features")

df = assembler.transform(df)

# %%
df.select('features').show(truncate=False)
# Out:
# +------------------------------------------------------------------------------------------------------------------------+
# |features                                                                                                                |
# +------------------------------------------------------------------------------------------------------------------------+
# |[40.0,156067.0,0.602,-6.667,0.404,0.658,0.0,0.0972,0.65,182.229,3.0,41.821917808219176,1.0,10807.0,80.0]                |
# |[43.0,220133.0,0.77,-7.306,0.172,0.543,7.96E-4,0.0684,0.898,135.573,4.0,45.824657534246576,1.0,19833.0,43.0]            |
# |[68.0,250960.0,0.212,-6.69,0.14,4.8E-5,0.918,0.324,0.231,140.917,4.0,25.673972602739727,0.0,874600.0,68.0]              |
# |[42.0,457040.0,0.362,-17.744,0.0398,0.144,0.827,0.117,0.257,118.853,4.0,31.813698630136987,0.0,69129.0,42.0]            |
# |[68.0,282891.0,0.343,-14.937,0.0384,0.957,2.49E-4,0.661,0.101,144.533,4.0,4.071232876712329,0.0,1709414.0,68.0]         |
# |[69.0,217000.0,0.893,-5.331,0.0362,0.119,9.76E-4,0.0952,0.958,120.021,4.0,13.802739726027397,1.0,2092689.0,69.0]        |
# |[63.0,545107.0,0.351,-17.481,0.0413,0.96,0.0339,0.083,0.237,107.86,4.0,71.84109589041095,1.0,3843344.0,126.0]           |
# |[37.0,256933.0,0.422,-3.806,0.0799,0.168,0.0,0.129,0.616,97.573,4.0,6.6657534246575345,0.0,5109.0,37.0]                 |
# |[68.0,249133.0,0.627,-5.604,0.0694,0.775,0.0,0.0886,0.891,152.277,4.0,30.624657534246577,0.0,800059.0,68.0]             |
# |[32.0,189800.0,0.554,-14.1,0.0438,0.971,0.0,0.142,0.549,103.292,1.0,20.805479452054794,1.0,930.0,32.0]                  |
# |[58.666666666666664,181733.0,0.189,-14.585,0.0359,0.945,0.831,0.309,0.218,77.6,4.0,61.83561643835616,1.0,299033.0,176.0]|
# |[59.0,203000.0,0.46,-6.641,0.105,0.0904,7.42E-6,0.118,0.473,116.004,4.0,38.46849315068493,1.0,147837.0,59.0]            |
# |[51.0,213240.0,0.764,-10.076,0.0262,0.868,2.67E-6,0.0962,0.478,105.07,4.0,16.019178082191782,1.0,10781.0,51.0]          |
# |[46.0,282027.0,0.413,-10.474,0.0299,0.81,2.17E-6,0.0884,0.181,135.632,4.0,30.813698630136987,1.0,18355.0,46.0]          |
# |[57.0,161213.0,0.829,-13.349,0.218,0.69,0.0,0.0981,0.918,103.259,4.0,25.60821917808219,0.0,167088.0,57.0]               |
# |[75.0,237760.0,0.632,-4.683,0.0294,0.0451,0.00122,0.21,0.832,108.045,4.0,33.010958904109586,1.0,1412267.0,75.0]         |
|
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# variance treshold per eliminare gli attributi con basssa varianza (minore di 1)

# %%
from pyspark.ml.feature import VarianceThresholdSelector

selector = VarianceThresholdSelector(varianceThreshold=1,featuresCol='scaledFeatures', outputCol="selectedFeatures")

df = selector.fit(df).transform(df)

print("Output: Features with variance lower than %f are removed." %
      selector.getVarianceThreshold())
# Out:
# Output: Features with variance lower than 1.000000 are removed.

# %%
df.select('selectedFeatures').show(truncate=False)
# Out:
# +------------------------------------------------------------+
# |selectedFeatures                                            |
# +------------------------------------------------------------+
# |[2.2425341538160897,0.5274762018580152,1.827589589002979]   |
# |[0.9547422635058598,0.3711869568630478,2.0025066141935035]  |
# |[0.7771157958768627,1.7582540061933842,1.1219352793021238]  |
# |[0.22092291911356524,0.6349250577920554,1.3902371639372808] |
# |[0.2131517611547966,3.5870552410303302,0.1779101296599035]  |
# |[0.20093994150530306,0.5166227820666981,0.6031704126693095] |
# |[0.2292491597836745,0.45041692133966327,3.139407415842523]  |
# |[0.44351108636115233,0.7000455765399586,0.29128892695999004]|
# |[0.38522740167038766,0.48080649675535136,1.338276870348857] |
# |[0.24312622756718988,0.7705928051835201,0.9091854136186455] |
# |[0.1992746933712812,1.6768533577585054,2.7021747149556]     |
# |[0.5828368469076469,0.640351767687714,1.68104719418217]     |
# |[0.14543167037124144,0.5220494919623566,0.7000272732984225] |
# |[0.16596973069084422,0.4797211547762197,1.3465378386843436] |
# |[1.2100803107225433,0.532360240764108,1.1190618990115195]   |
# |[0.16319431713414115,1.1396090780883046,1.4425566300620303] |
# |[0.3263886342682823,3.880097575395894,0.2617170548025229]   |
# |[2.403508140104868,3.223465678021204,0.22903235399690133]   |
# |[0.44240092093847105,0.5030560073275516,0.02202924889463139]|
# |[0.9658439177326721,1.7039869072367984,0.11254072804866036] |
# +------------------------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# SelectedFeatures = speechiness, liveness, age

# %% [markdown]
# # K-Means

# %%
from pyspark.ml.clustering import KMeans
from pyspark.ml.evaluation import ClusteringEvaluator
from pyspark.ml.clustering import KMeansModel

# %% [markdown]
# confronto silhouette score per scegliere il miglior numero di cluster

# %%
silhouette_score=[]
evaluator = ClusteringEvaluator(predictionCol='prediction', featuresCol='selectedFeatures', \
                                metricName='silhouette', distanceMeasure='squaredEuclidean')
for i in range(2,10):
    
    KMeans_algo=KMeans(featuresCol='selectedFeatures', k=i)
    
    KMeans_fit=KMeans_algo.fit(df)
    
    output=KMeans_fit.transform(df)
    
    
    
    score=evaluator.evaluate(output)
    
    silhouette_score.append(score)
    
    print("k={}, Silhouette Score:{}".format(i,score))
# Out:
# k=2, Silhouette Score:0.5166126813988047
# k=3, Silhouette Score:0.7027754912180209
# k=4, Silhouette Score:0.6188030511936338
# k=5, Silhouette Score:0.5553441559527094
# k=6, Silhouette Score:0.5482477622624944
# k=7, Silhouette Score:0.5173128113989679
# k=8, Silhouette Score:0.5108339629932724
# k=9, Silhouette Score:0.5155385931488722

# %%
# Trains a k-means model.
kmeans = KMeans(featuresCol='selectedFeatures', k=4)
model = kmeans.fit(df)

# Make predictions
predictions = model.transform(df)

# Evaluate clustering by computing Silhouette score
evaluator = ClusteringEvaluator()

silhouette = evaluator.evaluate(predictions)
print("Silhouette with squared euclidean distance = " + str(silhouette))

# Shows the result.
centers = model.clusterCenters()
print("Cluster Centers: ")
for center in centers:
    print(center)
# Out:
# Silhouette with squared euclidean distance = -0.6352428256314132
# Cluster Centers:
# [0.40061972 0.86353734 0.79206732]
# [4.84705963 2.05296189 2.03091133]
# [0.33774966 0.91381392 2.54167034]
# [0.51305821 3.71835118 1.3537786 ]

# %%
generi=predictions.groupBy("prediction","genres").count().orderBy(desc("prediction"), desc("count"))

# %%
generi.where(col('prediction')==1).show(100, truncate=False)
# Out:
# +----------+-----------------------------------------------------------------------------------------------------------------------------+-----+
# |prediction|genres                                                                                                                       |count|
# +----------+-----------------------------------------------------------------------------------------------------------------------------+-----+
# |1         |[hoerspiel]                                                                                                                  |7679 |
# |1         |[]                                                                                                                           |6181 |
# |1         |[kleine hoerspiel]                                                                                                           |1912 |
# |1         |[barnsagor]                                                                                                                  |1180 |
# |1         |[hoerspiel, kleine hoerspiel]                                                                                                |1024 |
# |1         |[hoerspiel, kleine hoerspiel, reading]                                                                                       |880  |
# |1         |[reading]                                                                                                                    |413  |
# |1         |[hoerspiel, kindermusik, kleine hoerspiel]                                                                                   |401  |
# |1         |[barnmusik, barnsagor]                                                                                                       |374  |
# |1         |[psychedelic rock]                                                                                                           |220  |
# |1         |[disney horspiele, kleine hoerspiel]                                                                                         |193  |
# |1         |[poetry]                                                                                                                     |184  |
# |1         |[barnmusik]                                                                                                                  |152  |
# |1         |[guidance, motivation, hoerspiel, kleine hoerspiel, reading]                                                                 |128  |
# |1         |[german literature]                                                                                                          |107  |
# |1         |[classic israeli pop]                                                                                                        |88   |
# |1         |[barnasogur]                                                                                                                 |85   |
# |1         |[chinderlieder, swiss folk]                                                                                                  |84   |
# |1         |[german rock, kabarett]                                                                                                      |75   |
# |1         |[kindermusik, kleine hoerspiel]                                                                                              |68   |
# |1         |[barnemusikk, classic norwegian pop, eventyr, norwegian pop, norwegian rock]                                                 |67   |
# |1         |[bornehistorier, bornesange]                                                                                                 |67   |
# |1         |[comedia]                                                                                                                    |67   |
# |1         |[barnalog, barnasogur, classic icelandic pop, icelandic pop]                                                                 |57   |
# |1         |[barnalog]                                                                                                                   |56   |
# |1         |[disney horspiele]                                                                                                           |51   |
# |1         |[barnalog, barnasogur]                                                                                                       |51   |
# |1         |[kindermusik]                                                                                                                |49   |
# |1         |[british comedy]                                                                                                             |48   |
# |1         |[comic]                                                                                                                      |44   |
# |1         |[cocuk masallari, turkish jazz]                                                                                              |43   |
# |1         |[mluvene slovo]                                                                                                              |43   |
# |1         |[classic soundtrack]                                                                                                         |40   |
# |1         |[chinderlieder]                                                                                                              |38   |
# |1         |[dutch trance, edm, pop dance, progressive house, trance]                                                                    |38   |
# |1         |[barnemusikk, eventyr]                                                                                                       |37   |
# |1         |[danish pop rock]                                                                                                            |37   |
# |1         |[fado]                                                                                                                       |35   |
# |1         |[bornehistorier]                                                                                                             |33   |
# |1         |[barnmusik, bornesange]                                                                                                      |33   |
# |1         |[bornesange]                                                                                                                 |33   |
# |1         |[barnalog, barnasogur, icelandic pop]                                                                                        |32   |
# |1         |[hangoskonyvek]                                                                                                              |32   |
# |1         |[muziek voor kinderen]                                                                                                       |29   |
# |1         |[broadway, hollywood]                                                                                                        |28   |
# |1         |[hoerspiel, kindermusik, kleine hoerspiel, reading]                                                                          |27   |
# |1         |[musiikkia lapsille, suomi rock]                                                                                             |27   |
# |1         |[classic israeli pop, israeli rock, israeli singer-songwriter]                                                               |25   |
# |1         |[musica para ninos]                                                                                                          |24   |
# |1         |[komedi, vintage swedish pop]                                                                                                |24   |
# |1         |[classic bollywood, classic pakistani pop, filmi, ghazal, sufi]                                                              |23   |
# |1         |[chanson, french pop, musique pour enfants]                                                                                  |21   |
# |1         |[classic icelandic pop]                                                                                                      |21   |
# |1         |[acoustic blues, appalachian folk, blues, country blues, delta blues, folk, texas blues, traditional blues, traditional folk]|21   |
# |1         |[australian comedy, australian rock]                                                                                         |20   |
# |1         |[detske pesnicky]                                                                                                            |20   |
# |1         |[chinderlieder, mundart, swiss folk, swiss hip hop, swiss indie]                                                             |20   |
# |1         |[oratory]                                                                                                                    |19   |
# |1         |[adult standards, easy listening, lounge, vocal jazz]                                                                        |19   |
# |1         |[mundart, swiss hip hop, swiss indie]                                                                                        |19   |
# |1         |[comedy, comic]                                                                                                              |18   |
# |1         |[bornehistorier, classic danish pop, dansktop]                                                                               |18   |
# |1         |[classic danish pop, dansktop]                                                                                               |17   |
# |1         |[barnemusikk, classic norwegian pop, eventyr]                                                                                |17   |
# |1         |[arkansas country, outlaw country]                                                                                           |17   |
# |1         |[dutch cabaret, vintage dutch pop]                                                                                           |16   |
# |1         |[romanian rap, romanian rock]                                                                                                |16   |
# |1         |[barnemusikk, classic norwegian pop]                                                                                         |16   |
# |1         |[chanson, french pop, french rock]                                                                                           |16   |
# |1         |[komedi]                                                                                                                     |16   |
# |1         |[east coast hip hop, gangster rap, hardcore hip hop, hip hop, pop rap, rap]                                                  |16   |
# |1         |[drama, vintage radio show]                                                                                                  |15   |
# |1         |[classic israeli pop, israeli rock]                                                                                          |15   |
# |1         |[british comedy, comedy, comic]                                                                                              |15   |
# |1         |[barnasogur, icelandic pop]                                                                                                  |15   |
# |1         |[celtic, irish folk, irish pub song, shanty]                                                                                 |14   |
# |1         |[beat poetry]                                                                                                                |14   |
# |1         |[adult standards, big band, jazz, jazz clarinet, lounge, stride, swing, vintage jazz, vocal jazz]                            |14   |
# |1         |[er ge]                                                                                                                      |14   |
# |1         |[slovak pop]                                                                                                                 |14   |
# |1         |[chanson]                                                                                                                    |14   |
# |1         |[classic danish pop, danish pop, dansktop]                                                                                   |14   |
# |1         |[vintage country folk]                                                                                                       |13   |
# |1         |[vintage swedish pop]                                                                                                        |13   |
# |1         |[bajki]                                                                                                                      |13   |
# |1         |[classic kollywood]                                                                                                          |13   |
# |1         |[american modern classical, poetry]                                                                                          |13   |
# |1         |[detskie rasskazy]                                                                                                           |12   |
# |1         |[dainuojamoji poezija, lithuanian pop]                                                                                       |12   |
# |1         |[adult standards, hollywood, lounge, torch song, vocal jazz]                                                                 |12   |
# |1         |[barnemusikk]                                                                                                                |12   |
# |1         |[german rock, liedermacher, ostrock]                                                                                         |12   |
# |1         |[detroit hip hop, hip hop, rap]                                                                                              |12   |
# |1         |[musiikkia lapsille]                                                                                                         |11   |
# |1         |[chutney, classic bollywood, desi pop, filmi, sufi]                                                                          |11   |
# |1         |["[""canadian childrens music""]                                                                                             |11   |
# |1         |[classic peruvian pop, musica afroperuana]                                                                                   |11   |
# |1         |[adult standards, dixieland, harlem renaissance, jazz trumpet, new orleans jazz, soul, swing, vocal jazz]                    |11   |
# |1         |[barnalog, classic icelandic pop]                                                                                            |11   |
# |1         |[classic bollywood, desi pop, filmi, modern bollywood, sufi]                                                                 |11   |
# +----------+-----------------------------------------------------------------------------------------------------------------------------+-----+
# only showing top 100 rows

# %%
generi.where(col('prediction')==3).show(100, truncate=False)
# Out:
# +----------+-----------------------------------------------------------------------------------------------------------------------------+-----+
# |prediction|genres                                                                                                                       |count|
# +----------+-----------------------------------------------------------------------------------------------------------------------------+-----+
# |3         |[]                                                                                                                           |3551 |
# |3         |[hoerspiel]                                                                                                                  |371  |
# |3         |[sertanejo, sertanejo pop, sertanejo universitario]                                                                          |293  |
# |3         |[classic israeli pop, israeli rock]                                                                                          |274  |
# |3         |[latin christian, latin worship]                                                                                             |253  |
# |3         |["[""canzone dautore""]                                                                                                      |196  |
# |3         |[album rock, art rock, classic rock, progressive rock, psychedelic rock, rock, symphonic rock]                               |192  |
# |3         |[classic italian pop, italian adult pop]                                                                                     |170  |
# |3         |[sertanejo, sertanejo universitario]                                                                                         |158  |
# |3         |[classic tollywood, filmi]                                                                                                   |145  |
# |3         |[sertanejo, sertanejo pop, sertanejo tradicional, sertanejo universitario]                                                   |144  |
# |3         |[classic rock, glam rock, rock]                                                                                              |135  |
# |3         |[greek pop, laiko]                                                                                                           |129  |
# |3         |[classical, late romantic era, operetta, classical performance, orchestral performance, austrian orchestra, orchestra]       |129  |
# |3         |[adult standards, rock-and-roll, rockabilly]                                                                                 |128  |
# |3         |[classic bollywood, desi pop, filmi, modern bollywood, sufi]                                                                 |128  |
# |3         |[dutch trance, edm, pop dance, progressive house, trance]                                                                    |112  |
# |3         |[british invasion, classic rock, rock]                                                                                       |111  |
# |3         |[adult standards, easy listening, lounge]                                                                                    |111  |
# |3         |[classic icelandic pop, icelandic pop, icelandic rock]                                                                       |111  |
# |3         |[axe, pagode]                                                                                                                |110  |
# |3         |[classic israeli pop]                                                                                                        |108  |
# |3         |[arab folk, belly dance, classic arab pop]                                                                                   |107  |
# |3         |[edm, pop dance, progressive house, progressive trance, trance, uplifting trance]                                            |102  |
# |3         |[rock uruguayo]                                                                                                              |102  |
# |3         |[filmi]                                                                                                                      |99   |
# |3         |[argentine rock, latin alternative, latin rock, rock en espanol, rock nacional]                                              |97   |
# |3         |[classic hungarian pop]                                                                                                      |97   |
# |3         |[kleine hoerspiel]                                                                                                           |96   |
# |3         |[classic bollywood, desi pop, filmi, sufi]                                                                                   |96   |
# |3         |[classic swedish pop, dansband, danspunk]                                                                                    |94   |
# |3         |[album rock, classic rock, country rock, folk, folk rock, mellow gold, rock, roots rock, singer-songwriter]                  |94   |
# |3         |[classic turkish pop]                                                                                                        |90   |
# |3         |[celtic, irish folk]                                                                                                         |90   |
# |3         |[classic israeli pop, israeli rock, israeli singer-songwriter]                                                               |89   |
# |3         |[adult standards, dixieland, harlem renaissance, jazz trumpet, new orleans jazz, soul, swing, vocal jazz]                    |88   |
# |3         |[hard rock, metal, old school thrash, rock, thrash metal]                                                                    |86   |
# |3         |[classic bollywood, classic tollywood, desi pop, filmi, sufi]                                                                |82   |
# |3         |[arabesk]                                                                                                                    |81   |
# |3         |[mariachi, ranchera]                                                                                                         |79   |
# |3         |[reggae, roots reggae]                                                                                                       |78   |
# |3         |[arkansas country, outlaw country]                                                                                           |77   |
# |3         |[adoracao, brazilian gospel]                                                                                                 |76   |
# |3         |[vintage taiwan pop]                                                                                                         |74   |
# |3         |[album rock, classic rock, glam rock, hard rock, metal, rock]                                                                |73   |
# |3         |[arab pop, classic arab pop, dabke, lebanese pop]                                                                            |73   |
# |3         |[argentine rock, latin alternative, latin rock, post-punk argentina, rock en espanol, ska argentino]                         |73   |
# |3         |[classic soundtrack]                                                                                                         |71   |
# |3         |[dance rock, new romantic, new wave, permanent wave, synthpop]                                                               |71   |
# |3         |[latin alternative, latin rock, rock en espanol, rock uruguayo]                                                              |71   |
# |3         |[chanson, french pop]                                                                                                        |70   |
# |3         |[adult standards, classic uk pop, mellow gold, neo soul, new wave pop, soft rock]                                            |70   |
# |3         |[adult standards, jazz blues, soul, soul jazz, torch song, vocal jazz]                                                       |69   |
# |3         |[irish rock, permanent wave, rock]                                                                                           |68   |
# |3         |[classic kollywood, filmi, tamil pop]                                                                                        |68   |
# |3         |[album rock, classic rock, mellow gold, rock, soft rock, yacht rock]                                                         |67   |
# |3         |[arabesk, turkish folk]                                                                                                      |67   |
# |3         |[classic kollywood, filmi]                                                                                                   |67   |
# |3         |[beatlesque, britpop, madchester, permanent wave, rock]                                                                      |66   |
# |3         |[cuarteto]                                                                                                                   |65   |
# |3         |[classic danish pop, dansktop]                                                                                               |65   |
# |3         |[adult standards, bebop, big band, cool jazz, hard bop, jazz, jazz piano, swing, vocal jazz]                                 |64   |
# |3         |[adult standards, jazz blues, swing, vocal jazz]                                                                             |63   |
# |3         |[cool jazz, hard bop, jazz, jazz fusion, jazz trumpet]                                                                       |63   |
# |3         |[c-pop, cantopop, classic cantopop]                                                                                          |61   |
# |3         |[album rock, german hard rock, german metal, german rock, hard rock, metal, rock]                                            |60   |
# |3         |[latin, latin pop]                                                                                                           |59   |
# |3         |[classic rock, heartland rock, mellow gold, permanent wave, rock, singer-songwriter]                                         |59   |
# |3         |[adult standards, harlem renaissance, jazz, jazz blues, lounge, soul, torch song, vocal jazz]                                |59   |
# |3         |[tango, vintage tango]                                                                                                       |58   |
# |3         |[bornesange]                                                                                                                 |58   |
# |3         |[classic bollywood, classic pakistani pop, filmi, ghazal, sufi]                                                              |58   |
# |3         |[messianic praise, tagalog worship, world worship, worship]                                                                  |58   |
# |3         |[austropop]                                                                                                                  |57   |
# |3         |[classic danish pop, danish pop]                                                                                             |57   |
# |3         |[classic soul, jazz blues, memphis soul, soul, southern soul]                                                                |57   |
# |3         |[australian rock, hard rock, rock]                                                                                           |57   |
# |3         |[cancion melodica, latin, latin pop, mariachi, ranchera, regional mexican]                                                   |56   |
# |3         |[chutney, classic bollywood, desi pop, filmi, sufi]                                                                          |56   |
# |3         |[beatlesque, british invasion, classic rock, merseybeat, psychedelic rock, rock]                                             |55   |
# |3         |[brazilian rock, mpb, pop rock brasileiro, rock gaucho, rock nacional brasileiro]                                            |54   |
# |3         |[funk carioca, sertanejo, sertanejo pop, sertanejo universitario]                                                            |54   |
# |3         |[german alternative rock, german pop, german punk, german rock]                                                              |53   |
# |3         |[celtic, irish folk, irish pub song, shanty]                                                                                 |52   |
# |3         |[album rock, classic rock, hard rock, rock]                                                                                  |52   |
# |3         |[adult standards, hollywood, lounge, torch song, vocal jazz]                                                                 |52   |
# |3         |[pop romantico]                                                                                                              |52   |
# |3         |[classical, late romantic era, operetta, classical performance, opera, orchestral performance, austrian orchestra, orchestra]|51   |
# |3         |[classic bollywood, desi pop, filmi, ghazal, sufi]                                                                           |51   |
# |3         |[argentine rock, latin alternative, latin rock, post-punk argentina, rock en espanol, rock nacional]                         |51   |
# |3         |[disco, mellow gold, soft rock]                                                                                              |51   |
# |3         |[album rock, art rock, blues rock, classic rock, hard rock, irish rock, metal, rock]                                         |50   |
# |3         |[classic rock, cosmic american, country rock, double drumming, folk rock, jam band, psychedelic rock, rock, roots rock]      |50   |
# |3         |[ccm, christian music, russian ccm, world worship, worship]                                                                  |49   |
# |3         |[turkish folk]                                                                                                               |49   |
# |3         |[anime score, japanese jazz, japanese jazz fusion]                                                                           |49   |
# |3         |[classical performance, orchestral performance, austrian orchestra, classical, orchestra]                                    |49   |
# |3         |[album rock, hard rock, metal, nwobhm, rock]                                                                                 |49   |
# |3         |[progressive house, progressive trance, trance, uplifting trance]                                                            |48   |
# |3         |[classic rock, folk rock, mellow gold, piano rock, rock, singer-songwriter, soft rock]                                       |48   |
# +----------+-----------------------------------------------------------------------------------------------------------------------------+-----+
# only showing top 100 rows

# %% [markdown]
# 0 pop\
# 1 audiolibri\
# 2 classica, vintage\
# 3 musica live\

# %% [markdown]
# # Bisecting K-means

# %%
from pyspark.ml.clustering import BisectingKMeans
from pyspark.ml.evaluation import ClusteringEvaluator

# %%
silhouette_score=[]
evaluator = ClusteringEvaluator(predictionCol='prediction', featuresCol='selectedFeatures', \
                                metricName='silhouette', distanceMeasure='squaredEuclidean')
for i in range(2,10):
    
    bkm = BisectingKMeans(featuresCol='selectedFeatures').setK(i).setSeed(1)
    
    model = bkm.fit(df)
    
    output=model.transform(df)
    
    
    
    score=evaluator.evaluate(output)
    
    silhouette_score.append(score)
    
    print("k={}, Silhouette Score:{}".format(i,score))
# Out:
# k=2, Silhouette Score:0.7415624288776014
# k=3, Silhouette Score:0.543198987271154
# k=4, Silhouette Score:0.6063931564082934
# k=5, Silhouette Score:0.5156639699250682
# k=6, Silhouette Score:0.4629157750322314
# k=7, Silhouette Score:0.4650012503021758
# k=8, Silhouette Score:0.4562108156548085
# k=9, Silhouette Score:0.40766863299654843

# %%
# Trains a bisecting k-means model.
bkm = BisectingKMeans(featuresCol='selectedFeatures').setK(4).setSeed(1)
model = bkm.fit(df)

# Make predictions
predictions = model.transform(df)

# Evaluate clustering by computing Silhouette score
evaluator = ClusteringEvaluator()

silhouette = evaluator.evaluate(predictions)
print("Silhouette with squared euclidean distance = " + str(silhouette))

# Shows the result.
print("Cluster Centers: ")
centers = model.clusterCenters()
for center in centers:
    print(center)
# Out:
# Silhouette with squared euclidean distance = -0.5429574238364241
# Cluster Centers:
# [0.38649703 0.89038973 0.79395606]
# [0.32490673 0.92299514 2.52324765]
# [0.6498445  3.8400005  1.41456087]
# [4.74552642 2.02605544 2.02572495]

# %%
generi=predictions.groupBy("prediction","genres").count().orderBy(desc("prediction"), desc("count"))

# %%
generi.where(col('prediction')==0).show(100, truncate=False)
# Out:
# +----------+------------------------------------------------------------------------------------------------------------+-----+
# |prediction|genres                                                                                                      |count|
# +----------+------------------------------------------------------------------------------------------------------------+-----+
# |0         |[]                                                                                                          |26828|
# |0         |[classic israeli pop, israeli rock]                                                                         |1224 |
# |0         |[c-pop, cantopop, classic cantopop]                                                                         |1158 |
# |0         |[greek pop, laiko]                                                                                          |1105 |
# |0         |[classic italian pop, italian adult pop]                                                                    |926  |
# |0         |[j-pop]                                                                                                     |910  |
# |0         |[indonesian pop]                                                                                            |862  |
# |0         |[classic thai pop]                                                                                          |840  |
# |0         |[classic icelandic pop, icelandic pop, icelandic rock]                                                      |826  |
# |0         |[turkish pop]                                                                                               |773  |
# |0         |[desi pop, filmi, modern bollywood, sufi]                                                                   |747  |
# |0         |[c-pop, cantopop]                                                                                           |701  |
# |0         |[thai pop]                                                                                                  |673  |
# |0         |[classic bollywood, desi pop, filmi, modern bollywood, sufi]                                                |664  |
# |0         |[j-pop, j-poprock, j-rock]                                                                                  |659  |
# |0         |[k-pop, k-pop boy group]                                                                                    |647  |
# |0         |[danish hip hop, danish pop]                                                                                |623  |
# |0         |[classic icelandic pop, icelandic pop]                                                                      |615  |
# |0         |[opm]                                                                                                       |612  |
# |0         |["[""canzone dautore""]                                                                                     |596  |
# |0         |[c-pop, classic mandopop, mandopop]                                                                         |589  |
# |0         |[filmi]                                                                                                     |555  |
# |0         |[arabesk]                                                                                                   |530  |
# |0         |[classic hungarian pop]                                                                                     |525  |
# |0         |[dance pop, pop, post-teen pop]                                                                             |510  |
# |0         |[israeli pop]                                                                                               |484  |
# |0         |[c-pop, cantopop, classic cantopop, classic mandopop, mandopop]                                             |483  |
# |0         |[rock uruguayo]                                                                                             |476  |
# |0         |[argentine rock, latin alternative, latin rock, rock en espanol, rock nacional]                             |476  |
# |0         |[slovak pop]                                                                                                |475  |
# |0         |[pop, post-teen pop]                                                                                        |470  |
# |0         |[filmi, tamil pop]                                                                                          |469  |
# |0         |[mandopop]                                                                                                  |467  |
# |0         |[classic israeli pop]                                                                                       |459  |
# |0         |[latvian pop]                                                                                               |458  |
# |0         |[turkish folk]                                                                                              |453  |
# |0         |[bulgarian pop, chalga]                                                                                     |452  |
# |0         |[cumbia uruguaya]                                                                                           |452  |
# |0         |[latin, reggaeton, reggaeton colombiano, trap latino]                                                       |451  |
# |0         |[latin christian, latin worship]                                                                            |449  |
# |0         |[classic swedish pop, dansband, danspunk]                                                                   |440  |
# |0         |[corrido, norteno, regional mexican]                                                                        |440  |
# |0         |[classic j-pop, j-pop, j-rock]                                                                              |434  |
# |0         |[polish hip hop, polish trap]                                                                               |430  |
# |0         |[sertanejo, sertanejo pop, sertanejo universitario]                                                         |426  |
# |0         |[classic icelandic pop]                                                                                     |423  |
# |0         |[classic danish pop, danish pop, dansktop]                                                                  |408  |
# |0         |[cumbia, vallenato]                                                                                         |405  |
# |0         |[c-pop, classic mandopop, vintage chinese pop]                                                              |405  |
# |0         |[chanson, french pop]                                                                                       |403  |
# |0         |[czech folk, czech rock]                                                                                    |403  |
# |0         |[finnish dance pop, finnish pop, iskelma, suomi rock]                                                       |403  |
# |0         |[classic j-pop, j-pop]                                                                                      |398  |
# |0         |[vallenato]                                                                                                 |393  |
# |0         |[cantopop]                                                                                                  |393  |
# |0         |[polish hip hop]                                                                                            |389  |
# |0         |[czech rock]                                                                                                |374  |
# |0         |[sertanejo, sertanejo pop, sertanejo tradicional, sertanejo universitario]                                  |368  |
# |0         |[anime, anime score, japanese classical, japanese soundtrack, soundtrack]                                   |362  |
# |0         |[arabesk, turkish folk]                                                                                     |362  |
# |0         |[classic malaysian pop, malaysian pop, rock kapak]                                                          |358  |
# |0         |[deep turkish pop, turkish pop]                                                                             |349  |
# |0         |[cumbia villera]                                                                                            |348  |
# |0         |[slovak pop, slovak rock]                                                                                   |344  |
# |0         |[c-pop, cantopop, classic cantopop, vintage chinese pop]                                                    |340  |
# |0         |[finnish dance pop, finnish hip hop, finnish pop]                                                           |335  |
# |0         |[folklore boliviano]                                                                                        |332  |
# |0         |[lithuanian pop]                                                                                            |331  |
# |0         |[classic russian rock, russian alternative rock, russian punk, russian punk rock, russian rock, russian ska]|330  |
# |0         |[latin, latin hip hop, reggaeton, reggaeton flow, trap latino, tropical]                                    |328  |
# |0         |[c-pop, cantopop, classic cantopop, classic mandopop]                                                       |324  |
# |0         |[contemporary country, country, country road]                                                               |324  |
# |0         |[classic israeli pop, israeli rock, israeli singer-songwriter]                                              |323  |
# |0         |[mariachi, ranchera]                                                                                        |322  |
# |0         |[corrido, norteno, ranchera, regional mexican]                                                              |322  |
# |0         |[latin, salsa, salsa puertorriquena, tropical]                                                              |321  |
# |0         |[classic danish pop, dansktop]                                                                              |321  |
# |0         |[latin, latin hip hop, reggaeton, trap latino, tropical]                                                    |320  |
# |0         |[estonian pop]                                                                                              |319  |
# |0         |[kayokyoku]                                                                                                 |314  |
# |0         |[turkish folk, turkish jazz]                                                                                |313  |
# |0         |[mandopop, taiwan pop]                                                                                      |311  |
# |0         |[panamanian pop]                                                                                            |310  |
# |0         |[edm, pop dance, progressive house, progressive trance, trance, uplifting trance]                           |307  |
# |0         |[czech hip hop, czsk hip hop]                                                                               |307  |
# |0         |[k-pop, k-pop girl group]                                                                                   |306  |
# |0         |[romanian rock]                                                                                             |305  |
# |0         |[israeli rock]                                                                                              |299  |
# |0         |[bachata, bachata dominicana, dominican pop, latin, tropical]                                               |293  |
# |0         |[classic finnish pop, classic iskelma, iskelma]                                                             |287  |
# |0         |[thai pop, thai rock]                                                                                       |284  |
# |0         |[beatlesque, britpop, madchester, permanent wave, rock]                                                     |283  |
# |0         |[polish pop]                                                                                                |282  |
# |0         |[bolero, latin, latin pop]                                                                                  |278  |
# |0         |[c-pop, mandopop, taiwan pop, zhongguo feng]                                                                |275  |
# |0         |[classic thai pop, thai pop]                                                                                |274  |
# |0         |[mariachi, ranchera, regional mexican]                                                                      |274  |
# |0         |[danish pop]                                                                                                |273  |
# |0         |[hard rock, metal, old school thrash, rock, thrash metal]                                                   |271  |
# |0         |[dutch pop, dutch rock]                                                                                     |271  |
# +----------+------------------------------------------------------------------------------------------------------------+-----+
# only showing top 100 rows

# %% [markdown]
# 0: [pop]\
# 1 [classica]\
# 2 [audiolibri]\
# 3 [live]
